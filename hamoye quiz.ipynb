# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/harsh/Downloads/FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding="latin-1")
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df['Y2017'].mean()
# Out:
# 140.917764860268

# %%
y=[(2,4),(7,8),(1,5,9)]
x=y[1][-1]
print(x)
# Out:
# 8

# %% [markdown]
# #

# %%
df['Area'].unique().shape
# Out:
# (49,)

# %%
df['Item'].unique()
# Out:
# array(['Population', 'Grand Total', 'Vegetal Products', 'Animal Products',
#        'Cereals - Excluding Beer', 'Wheat and products',
#        'Rice and products', 'Barley and products', 'Maize and products',
#        'Rye and products', 'Oats', 'Millet and products',
#        'Sorghum and products', 'Cereals, Other', 'Starchy Roots',
#        'Cassava and products', 'Potatoes and products', 'Sweet potatoes',
#        'Yams', 'Roots, Other', 'Sugar Crops', 'Sugar cane', 'Sugar beet',
#        'Sugar & Sweeteners', 'Sugar (Raw Equivalent)',
#        'Sweeteners, Other', 'Honey', 'Pulses', 'Beans', 'Peas',
#        'Pulses, Other and products', 'Treenuts', 'Nuts and products',
#        'Oilcrops', 'Soyabeans', 'Groundnuts (Shelled Eq)',
#        'Sunflower seed', 'Rape and Mustardseed', 'Cottonseed',
#        'Coconuts - Incl Copra', 'Sesame seed',
#        'Olives (including preserved)', 'Oilcrops, Other',
#        'Vegetable Oils', 'Soyabean Oil', 'Groundnut Oil',
# ...

# %%
df[['Y2015','Y2018']].groupby(df["Item"]).sum()
# Out:
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %%
a=df['Y2014'].dropna().count()
b=df['Y2014'].notnull().count()
b-a
# Out:
# 1589

# %%
my_tuppy = (1,2,5,8)
my_tuppy[2]=6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9716\2659888410.py in <module>
#       1 my_tuppy = (1,2,5,8)
# ----> 2 my_tuppy[2]=6
#
# TypeError: 'tuple' object does not support item assignment

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

db = pd.DataFrame(lst,index=['1','2','3'],columns= ['Age','Nationality','Overall'])
db
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age','Nationality','Overall']
pd.DataFrame(lst,columns=col,index=[i for i in range(1,4)])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
df=pd.read_csv("C:/Users/harsh/Downloads/FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding="latin-1")
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
y=df['Y2017'].groupby(df['Area']).sum()
y.max()
# Out:
# 1483268.23

# %%
S = [['him', 'sell'], [90, 28, 43]]
S[0][1][1]
# Out:
# 'e'

# %%
df['Element']
# Out:
# 0                 Total Population - Both sexes
# 1                      Domestic supply quantity
# 2                 Food supply (kcal/capita/day)
# 3        Protein supply quantity (g/capita/day)
# 4            Fat supply quantity (g/capita/day)
#                           ...
# 60938                                      Food
# 60939       Food supply quantity (kg/capita/yr)
# 60940             Food supply (kcal/capita/day)
# 60941    Protein supply quantity (g/capita/day)
# 60942        Fat supply quantity (g/capita/day)
# Name: Element, Length: 60943, dtype: object

# %%
df['Y2017'].groupby(df['Element']).sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
x=df[['Y2014','Y2015','Y2016','Y2017','Y2018']].groupby(df['Element']).sum()
x
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %%
x.groupby(df['Area']).count()
# Out:
# Series([], Name: Y2015, dtype: int64)

# %%
que1 = df[['Y2014','Y2015','Y2016','Y2017','Y2018']].groupby(df['Element Code']).corr()
que1
# Out:
#                        Y2014     Y2015     Y2016     Y2017     Y2018
# Element Code
# 511          Y2014  1.000000  0.999988  0.999951  0.999885  0.999791
#              Y2015  0.999988  1.000000  0.999987  0.999947  0.999878
#              Y2016  0.999951  0.999987  1.000000  0.999986  0.999944
#              Y2017  0.999885  0.999947  0.999986  1.000000  0.999986
#              Y2018  0.999791  0.999878  0.999944  0.999986  1.000000
# ...                      ...       ...       ...       ...       ...
# 5911         Y2014  1.000000  0.976942  0.992694  0.941934  0.942024
#              Y2015  0.976942  1.000000  0.965195  0.863665  0.863140
#              Y2016  0.992694  0.965195  1.000000  0.963790  0.963378
#              Y2017  0.941934  0.863665  0.963790  1.000000  0.999409
#              Y2018  0.942024  0.863140  0.963378  0.999409  1.000000
#
# [90 rows x 5 columns]

# %%
que2=df['Y2017'].groupby(df['Area']).sum()
print(que2)
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
que2.sort_values(ascending=True)
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...
